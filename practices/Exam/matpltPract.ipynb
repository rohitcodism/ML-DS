# %%
import numpy as np;
import matplotlib.pyplot as plt;

# %%
x = [1,2,3,4,5,6,7,8]
y = [2,4,5,6,7,6,8,9]

# %%
plt.plot(x,y, color='green', linewidth=1)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Test -1")
plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [2,4,5,6,7,6,8,9]

plt.plot(x,y, 'r*--')

# %%
plt.plot(x,y, color='r', linestyle='', marker="D", markersize='20')

# %%
plt.plot(x,y, color='r', linestyle='', marker="D", markersize='8', alpha=0.5)

# %%
a = [10,22,34,5,19,14,23,13,45]
b = [1,7,55,33,35,42,47,59,31.7]
c = [0,72,85,43,34,35,34,35,42]

plt.plot(a, label='report A')
plt.plot(b, label='report B')
plt.plot(c, label='report C')

plt.xlabel('values')
plt.ylabel('frequency')
plt.title('test 2')

plt.legend()

plt.grid()

# %%
A=[60,80,72,90,67]
B=[92,65,57,97,71]
Sub = [1-0.5,2-0.5,3-0.5,4-0.5,5-0.5]
Sub2 = [1.2,2.2,3.2,4.2,5.2]

plt.bar(Sub2, A, align='center', linewidth=5)
plt.bar(Sub,B, align='center', linewidth=5)
# Out:
# <BarContainer object of 5 artists>
