# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Line Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import  pandas as pd

# %%
var = [1,2,3,4,5,6,7]
var_1 = [2,3,4,1,5,6,7]

# %%
plt.plot(var, var_1)

# %%
sns.lineplot(x=var, y=var_1)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame({"var": var, "var_1": var_1})

# %%
sns.lineplot(x="var", y="var_1", data=df)
plt.show()

# %%
df = pd.read_csv('./Data-Sheet/penguins.csv')

# %%
df = df.head(20)

# %%
df
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x="bill_length_mm", y="bill_depth_mm", data=df)
plt.show()

# %%
sns.lineplot(x="bill_length_mm", y="flipper_length_mm", hue="sex",data=df, size=50, style="sex", palette="A")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     205                 # Perhaps a named matplotlib colormap?
# --> 206                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207             except ValueError:
#
# c:\Users\user\anaconda3\lib\site-packages\seaborn\palettes.py in mpl_palette(name, n_colors, as_cmap)
#     442     else:
# --> 443         cmap = mpl.cm.get_cmap(name)
#     444
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     285         return name
# --> 286     _api.check_in_list(sorted(_cmap_registry), name=name)
#     287     if lut is None:
#
# c:\Users\user\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
# ...

# %%
sns.lineplot(x="bill_length_mm", y="flipper_length_mm", hue="sex",data=df, size=50, style="sex", palette="Accent_r", markers=["o", ">"], dashes=False, legend="brief")
plt.grid()
plt.title("Python")
plt.show()
