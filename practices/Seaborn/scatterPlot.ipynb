# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../ML_NoteBook/05-Seaborn/dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(5,5), dpi=100)
sns.scatterplot(x="salary", y="sales", data=df, hue="level of education", palette="tab20c", legend=False, size="work experience", alpha=1, style="level of education")
plt.show()

plt.savefig('my_plot.png')

# %% [markdown]
# Distribution Plot

# %%
df = pd.read_csv("../ML_NoteBook/05-Seaborn/dm_office_sales.csv")

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(5,8), dpi=100)
sns.rugplot(x="salary", data=df, height=0.4)
plt.show()

# %%
#distplot is deprecated , dont use it.

sns.set_style(style='ticks')
sns.displot(data=df, x='salary', linewidth=2, kde=True, rug=True)

# %%
sns.histplot(data=df, x='salary', kde=True)
plt.show()

# %%
sns.kdeplot(data=df, x='salary')
plt.show()

# %%
np.random.seed(42)
sample_ages = np.random.randint(0, 100, 200)

# %%
sample_ages
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample_ages = pd.DataFrame(sample_ages, columns=['age'])

# %%
sample_ages
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages, x='age')
plt.show()

# %%
sns.displot(data=sample_ages, x='age', rug=True, bins=60, kde=True)

# %%
sns.kdeplot(data=sample_ages, x='age', clip=[0,100], bw_adjust=0.5, shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df6 = pd.read_csv('../Seaborn/Data-Sheet/diamonds.csv ')

# %%
df6
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.displot(x='cut', data=df6, hue='carat', legend=None, rug=True, kde=True, color='tab20c')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize=(10, 4), dpi=100)
sns.countplot(data=df, x='level of education', hue='division', palette='tab20c')
plt.show()

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.barplot(data=df, x='level of education', y='salary', estimator=np.mean, ci='sd', hue='division')
plt.legend(bbox_to_anchor=(1.1, 1))
plt.show()

# %%
sns.boxplot(data=df, y = 'salary', x='level of education', hue='division')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
sns.violinplot(data=df, x='level of education', y='salary', hue='division')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
sns.swarmplot(data=df, y = 'salary', x = 'level of education', hue='division')
# Out:
# c:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
sns.boxenplot(data=df, x='level of education', y='salary', hue='division')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
sns.boxplot(data=df, x='salary')
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.boxplot(data=df, y='level of education', x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='level of education'>

# %%
sns.kdeplot(data=df, x='salary', shade='R')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
sns.violinplot(data=df, y = 'salary', x='division', hue='level of education')
# Out:
# <AxesSubplot:xlabel='division', ylabel='salary'>

# %%
df7 = pd.read_csv('../ML_NoteBook/05-Seaborn/StudentsPerformance.csv')

# %%
df7
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(data=df7, y='math score')
# Out:
# <AxesSubplot:ylabel='math score'>

# %%
plt.figure(figsize=(4,4),dpi=100)
sns.boxplot(data=df7, y='math score', x='test preparation course')
plt.show()

# %%
plt.figure(figsize=(5,5), dpi=100)
sns.boxplot(data=df7, y='parental level of education', x='reading score', hue='test preparation course', palette='Set2')
plt.legend(bbox_to_anchor = (1.1, 1))
plt.show()

# %%
plt.figure(figsize=(5,5), dpi=100)
sns.violinplot(data=df7, y='parental level of education', x='reading score', hue='test preparation course', palette='Set2', split=True, inner='quartile')
plt.legend(bbox_to_anchor = (1.1, 1))
plt.show()

# %%
plt.figure(figsize=(8,4), dpi=100)
sns.swarmplot(data=df7, x='math score', y='gender', size=2, hue='test preparation course', dodge=True)
plt.legend(bbox_to_anchor = (1.5, 1))

# %%
sns.boxenplot(data=df7, x='math score', y='test preparation course', hue='gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>

# %%
sns.jointplot(data=df7, x='math score', y='reading score', hue='gender')

# %%
sns.pairplot(data=df7, hue='gender', corner=True, kind='kde')

# %%
sns.catplot(data=df7, x='math score', y='gender', kind='swarm', col='lunch', row='test preparation course')

# %%
g = sns.PairGrid(data=df7, hue='gender')
g = g.map_upper(sns.scatterplot)
g = g.map_lower(sns.kdeplot)
g = g.map_diag(sns.kdeplot, shade=True)
g = g.add_legend()
plt.legend(bbox_to_anchor = (1.5, 1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
g = sns.FacetGrid(data=df7, row='gender', col='lunch', hue='gender')
g = g.map(sns.histplot, 'math score', 'reading score')

# %%
df8 = pd.read_csv('../ML_NoteBook/05-Seaborn/country_table.csv')

# %%
df8.head()
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11

# %%
df8 = df8.set_index('Countries')

# %%
df8
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(df8)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
rates = df8.drop('Life expectancy', axis=1)

# %%
sns.heatmap(rates, linewidths=0.5,annot=True, cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.clustermap(rates, annot=True, cmap='viridis')
