# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def ccSlice(x):
    return (str(x)[-4:])

# %%
df['ccSlice'] = df['CC Number'].apply(ccSlice)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID ccSlice
# ...

# %%
print(ccSlice(1145729843922))
# Out:
# 3922

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID ccSlice
# 0  Christy Cunningham  3560325168603410    Sun2959    3410
# 1      Douglas Tucker  4478071379779230    Sun4608    9230
# 2      Travis Walters  6011812112971322    Sun4458    1322
# 3    Nathaniel Harris  4676137647685994    Sun5260    5994
# 4        Tonya Carter  4832732618637221    Sun2251    7221

# %%
def priceRating(x):
    if(x<=10):
        return '$'
    elif(x>10 and x<= 20):
        return '$$'
    elif(x>20 and x <= 30):
        return '$$$'
    elif(x>30 and x<=40):
        return '$$$$'
    else:
        return '$$$$$'

# %%
df['prRating'] = df['total_bill'].apply(priceRating)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID ccSlice prRating
# 0  Christy Cunningham  3560325168603410    Sun2959    3410       $$
# 1      Douglas Tucker  4478071379779230    Sun4608    9230       $$
# 2      Travis Walters  6011812112971322    Sun4458    1322      $$$
# 3    Nathaniel Harris  4676137647685994    Sun5260    5994      $$$
# 4        Tonya Carter  4832732618637221    Sun2251    7221      $$$

# %%
def Gen(total_bill, tip):
    ratio = tip/total_bill
    if ratio <= 0.25:
        return 'Avarage'
    else:
        return 'Generous'

# %%
Gen(16.69, 1.66)
# Out:
# 'Avarage'

# %%
df['tip_rating'] = df[['total_bill', 'tip']].apply(lambda df: Gen(df['total_bill'], df['tip']),axis=1)

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID ccSlice prRating tip_rating
# 0  Christy Cunningham  3560325168603410    Sun2959    3410       $$    Avarage
# ...

# %%
df['tip_rating'] = np.vectorize(Gen)(df['total_bill'], df['tip'])

# %%
df.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %%
import timeit

# %%
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def Gen(total_bill, tip):
    ratio = tip/total_bill
    if ratio <= 0.25:
        return 'Avarage'
    else:
        return 'Generous'
'''

# %%
st_1 = '''
df['tip_rating'] = df[['total_bill', 'tip']].apply(lambda df: Gen(df['total_bill'], df['tip']),axis=1)
'''

st_2 = '''
df['tip_rating'] = np.vectorize(Gen)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup=setup, stmt=st_1, number=1000)
# Out:
# 3.3943315999999992

# %%
timeit.timeit(setup=setup, stmt=st_2, number=1000)
# Out:
# 0.20145010000000063

# %%
df = pd.read_csv('tips.csv')

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.sort_values('total_bill', ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# ...

# %%
df.sort_values(['total_bill', 'tip']).head(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1              8.58
# ...

# %%
df.sort_index()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.loc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['sex'].replace(['Female', 'Male'], ['F', 'M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
myMap = { 'Female':'F', 'Male':'M' }

# %%
df['sex'].map(myMap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].between(10,20,inclusive='both')
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df.nlargest(5,'tip')
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.nsmallest(10,'total_bill')
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 149        7.51  2.00    Male     No  Thur   Lunch     2              3.76
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2              3.87
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
#
#           Payer Name         CC Number Payment ID
# 67     Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 160       21.50  3.50    Male     No   Sun  Dinner     4              5.38
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3             15.12
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 139       13.16  2.75  Female     No  Thur   Lunch     2              6.58
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
#
#           Payer Name         CC Number Payment ID
# 160  Travis Gonzalez  3527668419764685     Sun245
# 182     Jose Parsons  4112207559459910    Sun2337
# 225   Whitney Arnold  3579111947217428    Fri6665
# 139    Lindsey Meyer      676239597203   Thur6245
# 67     Tiffany Brock  4359488526995267    Sat3455

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 120       11.69  2.31    Male     No  Thur   Lunch     2              5.84
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2             17.32
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2              6.08
# 65        20.08  3.15    Male     No   Sat  Dinner     3              6.69
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2              8.00
# 50        12.54  2.50    Male     No   Sun  Dinner     2              6.27
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2             12.60
# 121       13.42  1.68  Female     No  Thur   Lunch     2              6.71
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3              6.05
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# ...

# %%
df.sample(frac=0.05)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 137       14.15  2.00  Female     No  Thur   Lunch     2              7.08
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 116       29.93  5.07    Male     No   Sun  Dinner     4              7.48
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2              8.94
# 140       17.47  3.50  Female     No  Thur   Lunch     2              8.74
# 6          8.77  2.00    Male     No   Sun  Dinner     2              4.38
# 127       14.52  2.00  Female     No  Thur   Lunch     2              7.26
# ...
